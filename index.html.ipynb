# %%
<!DOCTYPE html>
<html lang="es">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <meta name="description" content="Albergue ANA DOG LOVER - Ayuda a 50 perros rescatados en Huancayo. Donaciones, adopciones y voluntariado con enfoque humanitario.">
    <meta name="keywords" content="albergue perros Huancayo, adopción perros, donación animal, voluntariado">
    <meta name="author" content="Universidad Peruana Los Andes - RSU">
    <title>ANA DOG LOVER | Albergue de perros - Huancayo</title>
    <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.0.0-beta3/css/all.min.css">
    <link rel="stylesheet" href="css/styles.css">
    <link rel="preconnect" href="https://fonts.googleapis.com">
    <link rel="preconnect" href="https://fonts.gstatic.com" crossorigin>
    <link href="https://fonts.googleapis.com/css2?family=Inter:opsz,wght@14..32,300;14..32,400;14..32,600;14..32,700;14..32,800&family=Playfair+Display:ital,wght@0,500;1,500&display=swap" rel="stylesheet">
</head>
<body>

    <!-- ===== HEADER / NAVEGACIÓN ===== -->
    <header class="header">
        <div class="container">
            <nav class="navbar">
                <div class="logo">
                    <i class="fas fa-paw"></i> ANA <span>DOG LOVER</span>
                </div>
                <button class="menu-toggle" id="menuToggle" aria-label="Menú">
                    <i class="fas fa-bars"></i>
                </button>
                <ul class="nav-menu" id="navMenu">
                    <li><a href="#inicio">Inicio</a></li>
                    <li><a href="#nosotros">Nosotros</a></li>
                    <li><a href="#ayudar">Cómo ayudar</a></li>
                    <li><a href="#adopciones">Adopciones</a></li>
                    <li><a href="#voluntariado">Voluntariado</a></li>
                    <li><a href="#contacto" class="btn-small">Contacto</a></li>
                </ul>
            </nav>
        </div>
    </header>

    <main>
        <!-- ===== HERO SECTION ===== -->
        <section id="inicio" class="hero">
            <div class="container hero-grid">
                <div class="hero-content">
                    <div class="hero-badge">Proyecto RSU - Universidad Peruana Los Andes</div>
                    <h1>50 perros rescatados <br> <span class="highlight-text">esperan una familia</span></h1>
                    <p>En Huancayo, el albergue ANA DOG LOVER lucha cada día contra el abandono. Con tu ayuda podemos darles comida, medicinas y el amor que merecen.</p>
                    <div class="hero-buttons">
                        <a href="#donar" class="btn btn-primary"><i class="fas fa-heart"></i> Donar ahora</a>
                        <a href="#adopciones" class="btn btn-secondary"><i class="fas fa-paw"></i> Adoptar</a>
                        <a href="#voluntariado" class="btn btn-outline"><i class="fas fa-hands-helping"></i> Voluntario</a>
                    </div>
                    <div class="trust-badge">
                        <i class="fas fa-check-circle"></i> Ayuda 100% verificada · Todo va directo al albergue
                    </div>
                </div>
                <div class="hero-image">
                    <div class="image-placeholder">
                        <img src="assets/img/hero-dogs.jpg" alt="Perros del albergue ANA DOG LOVER" onerror="this.src='https://placehold.co/600x500/f9e0cf/b85c1a?text=🐕+Perros+rescatados+ANA+DOG+LOVER'">
                        <div class="image-caption">"Ellos solo necesitan una oportunidad" - Ana, fundadora</div>
                    </div>
                </div>
            </div>
        </section>

        <!-- ===== STATS ===== -->
        <section class="stats-section">
            <div class="container stats-grid">
                <div class="stat-card">
                    <div class="stat-number" data-target="50">0</div>
                    <p>Perros rescatados</p>
                </div>
                <div class="stat-card">
                    <div class="stat-number" data-target="2016">0</div>
                    <p>Año de fundación</p>
                </div>
                <div class="stat-card">
                    <div class="stat-number" data-target="1">0</div>
                    <p>Fundadora incansable</p>
                </div>
                <div class="stat-card">
                    <div class="stat-number" data-target="0">0</div>
                    <p>Apoyo municipal actual</p>
                </div>
            </div>
        </section>

        <!-- ===== NOSOTROS + DIAGNÓSTICO ===== -->
        <section id="nosotros" class="about">
            <div class="container">
                <div class="section-header">
                    <span class="section-tag">Nuestra historia</span>
                    <h2>Tecnología con sentido humano</h2>
                    <p class="section-subtitle">Conoce la realidad del albergue y nuestro compromiso como futuros ingenieros</p>
                </div>
                <div class="about-grid">
                    <div class="about-text">
                        <p><strong>ANA DOG LOVER</strong> nació en 2016 en Chilca, Huancayo. Desde entonces, su fundadora Ana ha rescatado más de 50 perros en situación de abandono, maltrato o enfermedad. Sin embargo, el albergue opera con recursos mínimos: no recibe apoyo de la municipalidad, carece de un veterinario estable y los víveres son escasos.</p>
                        <p>Tras nuestro <strong>diagnóstico participativo</strong> (visitas, entrevistas y observación), identificamos que la necesidad más urgente <strong>NO es solo tecnológica</strong>: es hambre, falta de medicinas, limpieza y, sobre todo, <strong>acompañamiento afectivo</strong> para perros que han sufrido traumas.</p>
                        <div class="quote-box">
                            <i class="fas fa-quote-left"></i>
                            <p>Los perros necesitan comida, pero también caricias, paseos y la certeza de que no están solos. Por eso, nuestro proyecto pone lo humano primero.</p>
                            <cite>— Equipo RSU, Ingeniería de Sistemas</cite>
                        </div>
                    </div>
                    <div class="about-image">
                        <img src="assets/img/fundadora.jpg" alt="Ana con los perros del albergue" onerror="this.src='https://placehold.co/500x400/f3d9c2/a0522d?text=Ana+y+sus+perros'">
                    </div>
                </div>
            </div>
        </section>

        <!-- ===== NECESIDADES URGENTES ===== -->
        <section id="ayudar" class="needs">
            <div class="container">
                <div class="section-header">
                    <span class="section-tag">¿Cómo ayudar?</span>
                    <h2>Necesidades urgentes del albergue</h2>
                    <p class="section-subtitle">Tu aporte, grande o pequeño, transforma vidas</p>
                </div>
                <div class="needs-grid">
                    <div class="need-card">
                        <i class="fas fa-dog"></i>
                        <h3>Alimento para perros</h3>
                        <p>Croquetas adulto y cachorro, comida húmeda, snacks.</p>
                        <span class="urgent-badge">Urgente</span>
                    </div>
                    <div class="need-card">
                        <i class="fas fa-capsules"></i>
                        <h3>Medicinas básicas</h3>
                        <p>Antiparasitarios, vacunas (séxtuple, antirrábica), vendas, alcohol.</p>
                    </div>
                    <div class="need-card">
                        <i class="fas fa-broom"></i>
                        <h3>Insumos de limpieza</h3>
                        <p>Lejía, escobas, guantes, bolsas grandes, mangueras.</p>
                    </div>
                    <div class="need-card">
                        <i class="fas fa-hand-holding-heart"></i>
                        <h3>Acompañamiento afectivo</h3>
                        <p>Voluntarios para pasear, jugar y socializar a los perros tímidos.</p>
                    </div>
                </div>

                <!-- DONACIONES ECONÓMICAS -->
                <div id="donar" class="donation-card">
                    <h3><i class="fas fa-hand-holding-usd"></i> Donación económica segura</h3>
                    <p>Con solo S/ 10 ayudas a alimentar a un perrito por 3 días. 100% de lo recaudado va directo al albergue.</p>
                    <div class="payment-methods">
                        <div class="payment-item">
                            <i class="fab fa-yape" style="font-weight: bold;">Yape</i>
                            <span>999 888 777</span>
                            <button class="copy-btn" data-copy="999888777">Copiar</button>
                        </div>
                        <div class="payment-item">
                            <i class="fas fa-mobile-alt"></i> Plin
                            <span>999 888 777</span>
                            <button class="copy-btn" data-copy="999888777">Copiar</button>
                        </div>
                        <div class="payment-item">
                            <i class="fas fa-building-columns"></i> Banco de la Nación
                            <span>Ana María Quispe - Cuenta de ahorros</span>
                        </div>
                    </div>
                    <div class="donation-note">
                        <i class="fas fa-info-circle"></i> Si donas víveres físicos, escríbenos para coordinar la entrega.
                    </div>
                </div>
            </div>
        </section>

        <!-- ===== GALERÍA DE PERROS EN ADOPCIÓN ===== -->
        <section id="adopciones" class="adoptions">
            <div class="container">
                <div class="section-header">
                    <span class="section-tag">Ellos necesitan un hogar</span>
                    <h2>Perritos en adopción responsable</h2>
                    <p class="section-subtitle">Conócelos, comparte y ayúdalos a encontrar una familia</p>
                </div>
                <div class="dogs-grid" id="dogsGrid">
                    <!-- Los perros se cargarán dinámicamente desde JS -->
                </div>
                <div class="adoption-cta">
                    <a href="#contacto" class="btn btn-primary"><i class="fas fa-paw"></i> Quiero adoptar o apadrinar</a>
                </div>
            </div>
        </section>

        <!-- ===== VOLUNTARIADO ===== -->
        <section id="voluntariado" class="volunteer">
            <div class="container volunteer-grid">
                <div class="volunteer-content">
                    <span class="section-tag">Únete a la causa</span>
                    <h2>¿Quieres ser voluntario?</h2>
                    <p>El albergue necesita manos amorosas. Puedes ayudar de muchas formas:</p>
                    <ul class="volunteer-list">
                        <li><i class="fas fa-paw"></i> Paseos y socialización con los perros</li>
                        <li><i class="fas fa-brush"></i> Limpieza y mantenimiento de espacios</li>
                        <li><i class="fas fa-camera"></i> Fotografía y difusión en redes sociales</li>
                        <li><i class="fas fa-truck"></i> Recolección de donaciones</li>
                    </ul>
                    <div class="volunteer-hours">
                        <i class="fas fa-clock"></i> Disponible fines de semana y horarios flexibles
                    </div>
                </div>
                <div class="volunteer-form" id="contacto">
                    <h3>Formulario de interés</h3>
                    <form id="contactForm">
                        <div class="form-group">
                            <input type="text" id="nombre" placeholder="Nombre completo" required>
                        </div>
                        <div class="form-group">
                            <input type="email" id="email" placeholder="Correo electrónico" required>
                        </div>
                        <div class="form-group">
                            <input type="tel" id="telefono" placeholder="Teléfono / WhatsApp">
                        </div>
                        <div class="form-group">
                            <select id="interes" required>
                                <option value="">¿Cómo quieres ayudar?</option>
                                <option value="adoptar">Adoptar un perrito</option>
                                <option value="voluntario">Ser voluntario presencial</option>
                                <option value="donar">Donar víveres o medicinas</option>
                                <option value="difusion">Difusión en redes</option>
                            </select>
                        </div>
                        <div class="form-group">
                            <textarea rows="3" placeholder="Cuéntanos algo más (opcional)"></textarea>
                        </div>
                        <button type="submit" class="btn btn-primary">Enviar mensaje <i class="fas fa-heart"></i></button>
                    </form>
                    <div id="formMessage" class="form-message"></div>
                </div>
            </div>
        </section>

        <!-- ===== PROYECTO RSU - INFORME ===== -->
        <section class="rsu-report">
            <div class="container">
                <div class="report-card">
                    <div class="report-icon">
                        <i class="fas fa-graduation-cap"></i>
                    </div>
                    <div class="report-content">
                        <h3>Proyecto de Responsabilidad Social Universitaria</h3>
                        <p><strong>Universidad Peruana Los Andes - Facultad de Ingeniería</strong> | Ingeniería de Sistemas y Computación</p>
                        <p>Este proyecto combina <strong>apoyo humanitario directo</strong> (limpieza, acompañamiento afectivo, donación de víveres) con <strong>soluciones tecnológicas</strong> (esta web para difusión y captación de ayudas). Hasta la fecha hemos logrado:</p>
                        <ul>
                            <li>✅ 30+ kg de croquetas donadas</li>
                            <li>✅ 2 jornadas de limpieza y socialización</li>
                            <li>✅ Página web implementada para visibilizar el albergue</li>
                            <li>✅ Apoyo emocional a la fundadora y voluntarios</li>
                        </ul>
                        <p><strong>Próximos pasos:</strong> Campañas en la universidad, alianza con clínicas veterinarias y seguimiento a adopciones.</p>
                    </div>
                </div>
            </div>
        </section>
    </main>

    <!-- ===== FOOTER ===== -->
    <footer class="footer">
        <div class="container">
            <div class="footer-grid">
                <div class="footer-info">
                    <div class="footer-logo">
                        <i class="fas fa-paw"></i> ANA <span>DOG LOVER</span>
                    </div>
                    <p>Dándoles una segunda oportunidad desde 2016.</p>
                    <div class="social-links">
                        <a href="#" aria-label="Facebook"><i class="fab fa-facebook-f"></i></a>
                        <a href="#" aria-label="Instagram"><i class="fab fa-instagram"></i></a>
                        <a href="#" aria-label="WhatsApp"><i class="fab fa-whatsapp"></i></a>
                        <a href="#" aria-label="TikTok"><i class="fab fa-tiktok"></i></a>
                    </div>
                </div>
                <div class="footer-contact">
                    <h4>Contacto</h4>
                    <p><i class="fas fa-map-marker-alt"></i> Jr. Arequipa 583, Chilca - Huancayo</p>
                    <p><i class="fas fa-phone"></i> +51 999 888 777</p>
                    <p><i class="fas fa-envelope"></i> anadoglover@ayuda.pe</p>
                </div>
                <div class="footer-hours">
                    <h4>Horario de visitas</h4>
                    <p>Lunes a Sábado: 9am - 5pm</p>
                    <p>Domingos y feriados: 10am - 2pm</p>
                    <p class="note">*Coordinar previamente para donaciones</p>
                </div>
            </div>
            <div class="footer-bottom">
                <p>&copy; 2026 ANA DOG LOVER - Proyecto RSU con enfoque humanitario</p>
                <p class="credits">Desarrollado por estudiantes de Ingeniería de Sistemas - Universidad Peruana Los Andes</p>
            </div>
        </div>
    </footer>

    <script src="js/main.js"></script>
</body>
</html>
